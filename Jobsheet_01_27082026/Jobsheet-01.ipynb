# %%
import pandas as pd
import numpy as np

df = pd.read_csv('transaksi_elektronikprima.csv')
df.head()
# Out:
#   id_transaksi     tanggal    cabang kategori_produk          nama_produk  \
# 0     TRX01409  2026-01-01  Surabaya          Laptop           Laptop A14
# 1     TRX00846  2026-01-01   Bandung      Smartphone   Smartphone MaxEdge
# 2     TRX01550  2026-01-01   Jakarta       Aksesoris       Mouse Wireless
# 3     TRX01622  2026-01-01   Jakarta          Laptop            Laptop X1
# 4     TRX01996  2026-01-01    Malang      Smartphone  Smartphone NovaLite
#
#    harga_satuan  jumlah_terjual  total_penjualan metode_pembayaran  \
# 0      14493000               1         14493000          E-Wallet
# 1       7967000               5         39835000            Kredit
# 2        126000               4           504000             Tunai
# 3      13021000               3         39063000            Kredit
# 4       5472000               2         10944000            Kredit
#
#   jenis_kelamin_pelanggan  usia_pelanggan  rating_kepuasan status_promo  \
# ...

# %%
df.shape
# Out:
# (2200, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_transaksi             2200 non-null   str
#  1   tanggal                  2200 non-null   str
#  2   cabang                   2200 non-null   str
#  3   kategori_produk          2200 non-null   str
#  4   nama_produk              2200 non-null   str
#  5   harga_satuan             2200 non-null   int64
#  6   jumlah_terjual           2200 non-null   int64
#  7   total_penjualan          2200 non-null   int64
#  8   metode_pembayaran        2200 non-null   str
#  9   jenis_kelamin_pelanggan  2200 non-null   str
#  10  usia_pelanggan           2068 non-null   float64
#  11  rating_kepuasan          2024 non-null   float64
#  12  status_promo             2200 non-null   str
#  13  biaya_iklan_harian       2200 non-null   int64
# dtypes: float64(2), int64(4), str(8)
# ...

# %%
df.describe()
# Out:
#        harga_satuan  jumlah_terjual  total_penjualan  usia_pelanggan  \
# count  2.200000e+03     2200.000000     2.200000e+03     2068.000000
# mean   4.871675e+06        3.075455     1.487367e+07       33.413926
# std    4.017403e+06        1.438361     1.508898e+07        8.729601
# min    5.100000e+04        1.000000     5.900000e+04       18.000000
# 25%    1.107250e+06        2.000000     2.372500e+06       27.000000
# 50%    4.506000e+06        3.000000     1.080100e+07       33.000000
# 75%    7.245500e+06        4.000000     2.249400e+07       39.000000
# max    1.498800e+07        7.000000     8.965800e+07       64.000000
#
#        rating_kepuasan  biaya_iklan_harian
# count      2024.000000        2.200000e+03
# mean          3.986166        1.678751e+06
# std           0.993208        8.858103e+05
# min           1.000000        2.020000e+05
# 25%           4.000000        9.470000e+05
# 50%           4.000000        1.659500e+06
# ...

# %%
df['cabang'].nunique()
# Out:
# 4

# %%
df['cabang'].unique()
# Out:
# <StringArray>
# ['Surabaya', 'Bandung', 'Jakarta', 'Malang']
# Length: 4, dtype: str

# %%
df['kategori_produk'].nunique()
# Out:
# 4

# %%
df['kategori_produk'].unique()
# Out:
# <StringArray>
# ['Laptop', 'Smartphone', 'Aksesoris', 'Elektronik Rumah Tangga']
# Length: 4, dtype: str

# %%
df[df['cabang'] == 'Bandung']
# Out:
#      id_transaksi     tanggal   cabang kategori_produk         nama_produk  \
# 1        TRX00846  2026-01-01  Bandung      Smartphone  Smartphone MaxEdge
# 7        TRX00773  2026-01-01  Bandung      Smartphone      Smartphone Air
# 10       TRX01949  2026-01-01  Bandung          Laptop      Laptop ProBook
# 11       TRX01237  2026-01-01  Bandung       Aksesoris      Mouse Wireless
# 18       TRX01175  2026-01-02  Bandung      Smartphone       Smartphone Z5
# ...           ...         ...      ...             ...                 ...
# 2181     TRX00347  2026-06-29  Bandung      Smartphone       Smartphone Z5
# 2186     TRX00820  2026-06-30  Bandung      Smartphone  Smartphone MaxEdge
# 2189     TRX00810  2026-06-30  Bandung      Smartphone      Smartphone Air
# 2197     TRX01056  2026-06-30  Bandung       Aksesoris  Earphone Bluetooth
# 2199     TRX01336  2026-06-30  Bandung          Laptop      Laptop ProBook
#
# ...

# %%
df[df['cabang'] == 'Bandung'].shape
# Out:
# (336, 14)

# %%
df[df['cabang'] == 'Bandung'].describe()
# Out:
#        harga_satuan  jumlah_terjual  total_penjualan  usia_pelanggan  \
# count  3.360000e+02      336.000000     3.360000e+02      309.000000
# mean   4.588039e+06        3.071429     1.397188e+07       33.025890
# std    3.918643e+06        1.345291     1.407037e+07        8.509695
# min    5.200000e+04        1.000000     1.010000e+05       18.000000
# 25%    4.547500e+05        2.000000     1.790500e+06       27.000000
# 50%    4.114000e+06        3.000000     1.058400e+07       33.000000
# 75%    6.871000e+06        4.000000     2.107400e+07       40.000000
# max    1.498800e+07        7.000000     6.604000e+07       59.000000
#
#        rating_kepuasan  biaya_iklan_harian
# count       303.000000        3.360000e+02
# mean          3.986799        1.635196e+06
# std           1.009798        9.177684e+05
# min           1.000000        2.020000e+05
# 25%           3.500000        9.025000e+05
# 50%           4.000000        1.635500e+06
# ...

# %%
df[df['kategori_produk'] == 'Smartphone']
# Out:
#      id_transaksi     tanggal    cabang kategori_produk          nama_produk  \
# 1        TRX00846  2026-01-01   Bandung      Smartphone   Smartphone MaxEdge
# 4        TRX01996  2026-01-01    Malang      Smartphone  Smartphone NovaLite
# 7        TRX00773  2026-01-01   Bandung      Smartphone       Smartphone Air
# 9        TRX00845  2026-01-01   Jakarta      Smartphone       Smartphone Air
# 16       TRX01279  2026-01-02    Malang      Smartphone   Smartphone MaxEdge
# ...           ...         ...       ...             ...                  ...
# 2187     TRX00161  2026-06-30    Malang      Smartphone        Smartphone Z5
# 2189     TRX00810  2026-06-30   Bandung      Smartphone       Smartphone Air
# 2191     TRX00511  2026-06-30    Malang      Smartphone  Smartphone NovaLite
# 2196     TRX01422  2026-06-30  Surabaya      Smartphone        Smartphone Z5
# 2198     TRX01117  2026-06-30    Malang      Smartphone        Smartphone Z5
#
# ...

# %%
df[df['kategori_produk'] == 'Smartphone']['metode_pembayaran'].nunique()
# Out:
# 4

# %%
df[df['kategori_produk'] == 'Smartphone']['metode_pembayaran'].unique()
# Out:
# <StringArray>
# ['Kredit', 'E-Wallet', 'Debit', 'Tunai']
# Length: 4, dtype: str

# %%
df['jumlah_terjual'].head()
# Out:
# 0    1
# 1    5
# 2    4
# 3    3
# 4    2
# Name: jumlah_terjual, dtype: int64
